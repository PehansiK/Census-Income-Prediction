# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load the dataset
df = pd.read_csv('Dataset/cleaned_labelEncoded_adult.csv')

# %%
df.head(10)
# Out:
#    age  workclass  fnlwgt  education-num  marital-status  occupation  \
# 0   39          5   77516              9               4           0
# 1   50          4   83311              9               2           3
# 2   38          2  215646              5               0           5
# 3   53          2  234721              3               2           5
# 4   28          2  338409              9               2           9
# 5   37          2  284582             10               2           3
# 6   49          2  160187              1               3           7
# 7   52          4  209642              5               2           3
# 8   31          2   45781             10               4           9
# 9   42          2  159449              9               2           3
#
#    relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0             1     4    1          2174             0              40
# ...
